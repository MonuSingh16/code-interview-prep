# %% [markdown]
# ### Central Limit Theorem
#
# Write a code that simulates CLT. What does CLT mean ? Using numpy how would you simulate CLT for any population distribution of your choice ?

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# Set the random seed
np.random.seed(123)

# %%
# Define the population distribution
population = np.random.uniform(low=0, high=1, size=100_000)

# Define the sample size and number of samples
sample_size = 100
num_samples = 1000 # The number of trials

# Calculate the means of num_samples of size sample_size
sample_means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]

# Plot the distribution of sample means
plt.hist(sample_means, bins=50, density=True)

# Plot the populations distribution for comparison
x = np.linspace(0, 1, 1000)
plt.plot(x, np.random.uniform(low=0, high=1, size=len(x)), 'r--')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.title('Central limit Theorem Demonstration')

plt.show()
